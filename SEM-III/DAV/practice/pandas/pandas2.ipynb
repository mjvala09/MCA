# %%
import pandas as pd

# %%
air_quality = pd.read_csv("air_quality.csv")

# %%
air_quality
# Out:
#                  datetime  station_antwerp  station_paris  station_london
# 0     2019-05-07 02:00:00              NaN            NaN            23.0
# 1     2019-05-07 03:00:00             50.5           25.0            19.0
# 2     2019-05-07 04:00:00             45.0           27.7            19.0
# 3     2019-05-07 05:00:00              NaN           50.4            16.0
# 4     2019-05-07 06:00:00              NaN           61.9             NaN
# ...                   ...              ...            ...             ...
# 1030  2019-06-20 22:00:00              NaN           21.4             NaN
# 1031  2019-06-20 23:00:00              NaN           24.9             NaN
# 1032  2019-06-21 00:00:00              NaN           26.5             NaN
# 1033  2019-06-21 01:00:00              NaN           21.8             NaN
# 1034  2019-06-21 02:00:00              NaN           20.0             NaN
#
# [1035 rows x 4 columns]

# %%
air_quality.head(8)
# Out:
#               datetime  station_antwerp  station_paris  station_london
# 0  2019-05-07 02:00:00              NaN            NaN            23.0
# 1  2019-05-07 03:00:00             50.5           25.0            19.0
# 2  2019-05-07 04:00:00             45.0           27.7            19.0
# 3  2019-05-07 05:00:00              NaN           50.4            16.0
# 4  2019-05-07 06:00:00              NaN           61.9             NaN
# 5  2019-05-07 07:00:00              NaN           72.4            26.0
# 6  2019-05-07 08:00:00              NaN           77.7            32.0
# 7  2019-05-07 09:00:00              NaN           67.9            32.0

# %%
air_quality.tail(8)
# Out:
#                  datetime  station_antwerp  station_paris  station_london
# 1027  2019-06-20 19:00:00              NaN           23.2             NaN
# 1028  2019-06-20 20:00:00              NaN           23.9             NaN
# 1029  2019-06-20 21:00:00              NaN           25.3             NaN
# 1030  2019-06-20 22:00:00              NaN           21.4             NaN
# 1031  2019-06-20 23:00:00              NaN           24.9             NaN
# 1032  2019-06-21 00:00:00              NaN           26.5             NaN
# 1033  2019-06-21 01:00:00              NaN           21.8             NaN
# 1034  2019-06-21 02:00:00              NaN           20.0             NaN

# %%
air_quality.plot()
# Out:
# <Axes: >

# %% [markdown]
# #### With a DataFrame, pandas creates by default one line plot for each of the columns with numeric data.

# %%
from matplotlib import pyplot as plt

# %%
air_quality["station_paris"].plot()                 # For only one column
plt.show()

# %%
air_quality.plot.scatter(x="station_paris", y="station_london", alpha=0.5,)
# compare the NO2 values measured in London versus Paris.
# Out:
# <Axes: xlabel='station_paris', ylabel='station_london'>

# %%
[

    method_name

    for method_name in dir(air_quality.plot)

    if not method_name.startswith("_")

]
# Out:
# ['area',
#  'bar',
#  'barh',
#  'box',
#  'density',
#  'hexbin',
#  'hist',
#  'kde',
#  'line',
#  'pie',
#  'scatter']

# %% [markdown]
# ## Separate subplots for each of the data columns are supported by the subplots argument of the plot functions. The builtin options available in each of the pandas plot functions are worth reviewing.

# %%
air_quality.plot.box()
# DataFrame.plot.box(), which refers to a boxplot.
# Out:
# <Axes: >

# %%
axs = air_quality.plot.area(figsize = (12,4), subplots=True)
plt.show()
# figsize = (12,4), refererse height and width of the plot

# %%
fig, axs = plt.subplots(figsize=(12, 4))
air_quality.plot.area(ax=axs)
axs.set_ylabel("NO$_2$ concentration")
fig.savefig("images/no2_concentrations.png")
plt.show()

# %%
air_quality['london_multi2'] = air_quality['station_london']*2

# %%
air_quality
# Out:
#                  datetime  station_antwerp  station_paris  station_london  \
# 0     2019-05-07 02:00:00              NaN            NaN            23.0
# 1     2019-05-07 03:00:00             50.5           25.0            19.0
# 2     2019-05-07 04:00:00             45.0           27.7            19.0
# 3     2019-05-07 05:00:00              NaN           50.4            16.0
# 4     2019-05-07 06:00:00              NaN           61.9             NaN
# ...                   ...              ...            ...             ...
# 1030  2019-06-20 22:00:00              NaN           21.4             NaN
# 1031  2019-06-20 23:00:00              NaN           24.9             NaN
# 1032  2019-06-21 00:00:00              NaN           26.5             NaN
# 1033  2019-06-21 01:00:00              NaN           21.8             NaN
# 1034  2019-06-21 02:00:00              NaN           20.0             NaN
#
#       london_multi2
# 0              46.0
# 1              38.0
# ...

# %%
air_quality["ratio_london_paris"]=air_quality["station_paris"]/air_quality["station_london"]
air_quality
# Out:
#                  datetime  station_antwerp  station_paris  station_london  \
# 0     2019-05-07 02:00:00              NaN            NaN            23.0
# 1     2019-05-07 03:00:00             50.5           25.0            19.0
# 2     2019-05-07 04:00:00             45.0           27.7            19.0
# 3     2019-05-07 05:00:00              NaN           50.4            16.0
# 4     2019-05-07 06:00:00              NaN           61.9             NaN
# ...                   ...              ...            ...             ...
# 1030  2019-06-20 22:00:00              NaN           21.4             NaN
# 1031  2019-06-20 23:00:00              NaN           24.9             NaN
# 1032  2019-06-21 00:00:00              NaN           26.5             NaN
# 1033  2019-06-21 01:00:00              NaN           21.8             NaN
# 1034  2019-06-21 02:00:00              NaN           20.0             NaN
#
#       london_multi2  ratio_london_paris
# ...

# %%
air_quality = air_quality.rename(
    columns={
        "station_paris":"paris",
        "station_london":"london",
        "station_antwerp":"antwerp",
    }
)
air_quality
# Out:
#                  datetime  antwerp  paris  london  london_multi2  \
# 0     2019-05-07 02:00:00      NaN    NaN    23.0           46.0
# 1     2019-05-07 03:00:00     50.5   25.0    19.0           38.0
# 2     2019-05-07 04:00:00     45.0   27.7    19.0           38.0
# 3     2019-05-07 05:00:00      NaN   50.4    16.0           32.0
# 4     2019-05-07 06:00:00      NaN   61.9     NaN            NaN
# ...                   ...      ...    ...     ...            ...
# 1030  2019-06-20 22:00:00      NaN   21.4     NaN            NaN
# 1031  2019-06-20 23:00:00      NaN   24.9     NaN            NaN
# 1032  2019-06-21 00:00:00      NaN   26.5     NaN            NaN
# 1033  2019-06-21 01:00:00      NaN   21.8     NaN            NaN
# 1034  2019-06-21 02:00:00      NaN   20.0     NaN            NaN
#
#       ratio_london_paris
# 0                    NaN
# 1               1.315789
# 2               1.457895
# 3               3.150000
# 4                    NaN
# ...                  ...
# ...

# %%
titanic = pd.read_csv('titanic.csv')
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## Different statistics are available and can be applied to columns with numerical data. Operations in general exclude missing data and operate across rows by default.

# %%
titanic['Age'].mean()
# Out:
# 29.69911764705882

# %%
titanic[['Age', 'Fare']].median()
# Out:
# Age     28.0000
# Fare    14.4542
# dtype: float64

# %%
titanic.agg(
    {
        "Age":["min","max","median","skew"],
        "Fare":["min","max","median","mean"],
    }
)
# Out:
#               Age        Fare
# min      0.420000    0.000000
# max     80.000000  512.329200
# median  28.000000   14.454200
# skew     0.389108         NaN
# mean          NaN   32.204208

# %%
titanic[['Age','Sex']].groupby("Sex").mean()
# Out:
#               Age
# Sex
# female  27.915709
# male    30.726645

# %% [markdown]
# As our interest is the average age for each gender, a subselection on these two columns is made first: titanic[["Sex", "Age"]]. Next, the groupby() method is applied on the Sex column to make a group per category. The average age for each gender is calculated and returned.
#
# Calculating a given statistic (e.g. mean age) for each category in a column (e.g. male/female in the Sex column) is a common pattern. The groupby method is used to support this type of operations. This fits in the more general split-apply-combine pattern:
#
# Split the data into grou ps
#
# Apply a function to each group independe ntly
#
# Combine the results into a data structure
#
# The apply and combine steps are typically done together in pandas.
#
# In the previous example, we explicitly selected the 2 columns first. If not, the mean method is applied to each column containing numerical columns by passing numeric_only=True:

# %%
titanic.groupby("Sex").mean(numeric_only=True)
# Out:
#         PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Sex
# female   431.028662  0.742038  2.159236  27.915709  0.694268  0.649682
# male     454.147314  0.188908  2.389948  30.726645  0.429809  0.235702
#
#              Fare
# Sex
# female  44.479818
# male    25.523893

# %%
titanic.groupby('Sex')['Age'].mean()
# Out:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %%
titanic.groupby(["Sex","Pclass"])["Fare"].mean()
# Out:
# Sex     Pclass
# female  1         106.125798
#         2          21.970121
#         3          16.118810
# male    1          67.226127
#         2          19.741782
#         3          12.661633
# Name: Fare, dtype: float64

# %%
titanic["Pclass"].value_counts(ascending=True)
# Out:
# Pclass
# 2    184
# 1    216
# 3    491
# Name: count, dtype: int64

# %%
titanic.groupby('Pclass')['Pclass'].count()
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: Pclass, dtype: int64

# %% [markdown]
# ##### Both size and count can be used in combination with groupby. Whereas size includes NaN values and just provides the number of rows (size of the table), count excludes the missing values. In the value_counts method, use the dropna argument to include or exclude the NaN values.

# %%
air_quality_long = pd.read_csv(
    "air_quality_long.csv", index_col="date.utc", parse_dates=True
)
air_quality_long
# Out:
#                                 city country            location parameter  \
# date.utc
# 2019-06-18 06:00:00+00:00  Antwerpen      BE             BETR801      pm25
# 2019-06-17 08:00:00+00:00  Antwerpen      BE             BETR801      pm25
# 2019-06-17 07:00:00+00:00  Antwerpen      BE             BETR801      pm25
# 2019-06-17 06:00:00+00:00  Antwerpen      BE             BETR801      pm25
# 2019-06-17 05:00:00+00:00  Antwerpen      BE             BETR801      pm25
# ...                              ...     ...                 ...       ...
# 2019-04-09 06:00:00+00:00     London      GB  London Westminster       no2
# 2019-04-09 05:00:00+00:00     London      GB  London Westminster       no2
# 2019-04-09 04:00:00+00:00     London      GB  London Westminster       no2
# 2019-04-09 03:00:00+00:00     London      GB  London Westminster       no2
# 2019-04-09 02:00:00+00:00     London      GB  London Westminster       no2
#
#                            value   unit
# date.utc
# ...

# %%
titanic = pd.read_csv("titanic.csv")
titanic.sort_values(by="Age").dropna()
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 305          306         1       1        Allison, Master. Hudson Trevor
# 183          184         1       2             Becker, Master. Richard F
# 297          298         0       1          Allison, Miss. Helen Loraine
# 205          206         0       3            Strom, Miss. Telma Matilda
# 340          341         1       2        Navratil, Master. Edmond Roger
# ..           ...       ...     ...                                   ...
# 54            55         0       1        Ostby, Mr. Engelhart Cornelius
# 456          457         0       1             Millet, Mr. Francis Davis
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 96            97         0       1             Goldschmidt, Mr. George B
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#         Sex    Age  SibSp  Parch     Ticket      Fare    Cabin Embarked
# ...

# %%
titanic.sort_values(by=["Pclass","Age"], ascending=False).dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 699          700         0       3
# 429          430         1       3
# 251          252         0       3
# 823          824         1       3
# 75            76         0       3
# ..           ...       ...     ...
# 435          436         1       1
# 802          803         1       1
# 445          446         1       1
# 297          298         0       1
# 305          306         1       1
#
#                                            Name     Sex    Age  SibSp  Parch  \
# 699    Humblen, Mr. Adolf Mathias Nicolai Olsen    male  42.00      0      0
# 429          Pickard, Mr. Berk (Berk Trembisky)    male  32.00      0      0
# 251  Strom, Mrs. Wilhelm (Elna Matilda Persson)  female  29.00      1      1
# 823                          Moor, Mrs. (Beila)  female  27.00      0      1
# 75                      Moen, Mr. Sigurd Hansen    male  25.00      0      0
# ...

# %%
import matplotlib.pyplot as plt

temperatures = [20, 22, 25, 27, 30]
humidities = [60, 65, 70, 75, 80]

plt.scatter(temperatures, humidities)
plt.xlabel("Temperature (°C)")
plt.ylabel("Humidity (%)")
plt.title("Temperature vs. Humidity")
plt.grid(True)  # Enable the grid
plt.show()

# %%
import matplotlib.pyplot as plt

years = [2018, 2019, 2020, 2021, 2022]
company1_growth_rates = [10, 12, 15, 18, 20]
company2_growth_rates = [8, 9, 11, 13, 16]

plt.plot(years, company1_growth_rates, label='Company 1', color='blue')
plt.plot(years, company2_growth_rates, label='Company 2', color='green')
plt.xlabel("Year")
plt.ylabel("Growth Rate (%)")
plt.title("Growth Rate Comparison")
plt.legend()  # Add the legend
plt.show()

# %%
import matplotlib.pyplot as plt
scores = [75, 82, 91, 85, 77, 90, 88, 93, 89, 81]
plt.hist(scores)
plt.xlabel("Test Score")
plt.ylabel("Frequency")
plt.title("Distribution of Test Scores")
plt.show()

# %%
student_grades = {
  "Math": 85,
  "Science": 92,
  "English": 78,
  "History": 90,
  "Art": 82
}
import matplotlib.pyplot as plt

subjects = list(student_grades.keys())
grades = list(student_grades.values())

# Create the polar chart
plt.figure(figsize=(8, 8))
ax = plt.subplot(111, polar=True)

# Set labels for each axis
ax.set_theta_zero_location("N")  # Set starting angle at North
ax.set_theta_direction(-1)  # Set clockwise rotation
ax.set_thetagrids(range(0, 360, 45), labels=subjects)

# Plot data points
ax.plot(range(0, 360, 45), grades, marker='o', linestyle='-', label='Student Grades')

# Add title and legend
plt.title("Student Performance in Different Subjects")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\DAV\practice\pandas\pandas2.ipynb Cell 39 line 2
#      <a href='vscode-notebook-cell:/d%3A/DAV/practice/pandas/pandas2.ipynb#X53sZmlsZQ%3D%3D?line=17'>18</a> ax.set_theta_zero_location("N")  # Set starting angle at North
#      <a href='vscode-notebook-cell:/d%3A/DAV/practice/pandas/pandas2.ipynb#X53sZmlsZQ%3D%3D?line=18'>19</a> ax.set_theta_direction(-1)  # Set clockwise rotation
# ---> <a href='vscode-notebook-cell:/d%3A/DAV/practice/pandas/pandas2.ipynb#X53sZmlsZQ%3D%3D?line=19'>20</a> ax.set_thetagrids(range(0, 360, 45), labels=subjects)
#      <a href='vscode-notebook-cell:/d%3A/DAV/practice/pandas/pandas2.ipynb#X53sZmlsZQ%3D%3D?line=21'>22</a> # Plot data points
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

def hill_function(x, y):
  return 10 * np.sin(np.pi * x) * np.cos(np.pi * y)

# Generate a grid of x and y values
x = np.linspace(-2, 2, 100)
y = np.linspace(-2, 2, 100)

# Evaluate the hill function at each grid point
z = hill_function(x, y)
z.shape = (2,50)
print(z.shape)

# Create the contour plot
plt.contourf(x, y, z, cmap='viridis')
plt.colorbar()
plt.title('Hill Function Contour Plot')
plt.show()
# Out:
# (2, 50)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\DAV\practice\pandas\pandas2.ipynb Cell 40 line 1
#      <a href='vscode-notebook-cell:/d%3A/DAV/practice/pandas/pandas2.ipynb#X54sZmlsZQ%3D%3D?line=13'>14</a> print(z.shape)
#      <a href='vscode-notebook-cell:/d%3A/DAV/practice/pandas/pandas2.ipynb#X54sZmlsZQ%3D%3D?line=15'>16</a> # Create the contour plot
# ---> <a href='vscode-notebook-cell:/d%3A/DAV/practice/pandas/pandas2.ipynb#X54sZmlsZQ%3D%3D?line=16'>17</a> plt.contourf(x, y, z, cmap='viridis')
#      <a href='vscode-notebook-cell:/d%3A/DAV/practice/pandas/pandas2.ipynb#X54sZmlsZQ%3D%3D?line=17'>18</a> plt.colorbar()
#      <a href='vscode-notebook-cell:/d%3A/DAV/practice/pandas/pandas2.ipynb#X54sZmlsZQ%3D%3D?line=18'>19</a> plt.title('Hill Function Contour Plot')
#
# ...
